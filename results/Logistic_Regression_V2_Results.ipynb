# %%
import sys
sys.path.insert(0, '/home/brian/Desktop/Projects/final_year_project/models')

# %%
import Logistic_Regression_Model_V2
import matplotlib.pyplot as plt
import datetime

# %%
stock_models = {}
stock_accuracy = {}
stock_f1_scores = {}
stock_roc_curves = {}

tickers = ["GOOG", "MSFT", "AMZN", "AAPL", "META"]

# %%
start = datetime.datetime(2008, 1, 1)
end = datetime.datetime(2023, 12, 31)

stock_accuracy = {}
stock_f1_scores = {}

# %%
for ticker in tickers:
    stock_models[ticker] = Logistic_Regression_Model_V2.Logistic_Regression_Model_V2(ticker, start, end)
    stock_accuracy[ticker], stock_f1_scores[ticker ] = stock_models[ticker].get_metrics()
    stock_roc_curves[ticker] = stock_models[ticker].get_roc_curve()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RSI_'+f'{leng}'] = ta.rsi(data[self.ticker], length=leng)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RSI_'+f'{leng}'] = ta.rsi(data[self.ticker], length=leng)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Stoch_Oscillator'] = stochk
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Williams_%R'] = williams_r
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ADX'] = adx['ADX_14']
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['returns'] = np.log(data[self.ticker] / data[self.ticker].shift(1)).shift(-1)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['direction'] = [1 if data.returns[i]>0 else 0 for i in range(len(data))]
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[features_for_scaling] = Logistic_Regression_Model_V2.sc.fit_transform(data[features_for_scaling])
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RSI_'+f'{leng}'] = ta.rsi(data[self.ticker], length=leng)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RSI_'+f'{leng}'] = ta.rsi(data[self.ticker], length=leng)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Stoch_Oscillator'] = stochk
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Williams_%R'] = williams_r
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ADX'] = adx['ADX_14']
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['returns'] = np.log(data[self.ticker] / data[self.ticker].shift(1)).shift(-1)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['direction'] = [1 if data.returns[i]>0 else 0 for i in range(len(data))]
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[features_for_scaling] = Logistic_Regression_Model_V2.sc.fit_transform(data[features_for_scaling])
# [*********************100%%**********************]  1 of 1 completed
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RSI_'+f'{leng}'] = ta.rsi(data[self.ticker], length=leng)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RSI_'+f'{leng}'] = ta.rsi(data[self.ticker], length=leng)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Stoch_Oscillator'] = stochk
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Williams_%R'] = williams_r
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ADX'] = adx['ADX_14']
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['returns'] = np.log(data[self.ticker] / data[self.ticker].shift(1)).shift(-1)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['direction'] = [1 if data.returns[i]>0 else 0 for i in range(len(data))]
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[features_for_scaling] = Logistic_Regression_Model_V2.sc.fit_transform(data[features_for_scaling])
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RSI_'+f'{leng}'] = ta.rsi(data[self.ticker], length=leng)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RSI_'+f'{leng}'] = ta.rsi(data[self.ticker], length=leng)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Stoch_Oscillator'] = stochk
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Williams_%R'] = williams_r
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ADX'] = adx['ADX_14']
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['returns'] = np.log(data[self.ticker] / data[self.ticker].shift(1)).shift(-1)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['direction'] = [1 if data.returns[i]>0 else 0 for i in range(len(data))]
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[features_for_scaling] = Logistic_Regression_Model_V2.sc.fit_transform(data[features_for_scaling])
# [*********************100%%**********************]  1 of 1 completed
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RSI_'+f'{leng}'] = ta.rsi(data[self.ticker], length=leng)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RSI_'+f'{leng}'] = ta.rsi(data[self.ticker], length=leng)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Stoch_Oscillator'] = stochk
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Williams_%R'] = williams_r
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ADX'] = adx['ADX_14']
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['returns'] = np.log(data[self.ticker] / data[self.ticker].shift(1)).shift(-1)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['direction'] = [1 if data.returns[i]>0 else 0 for i in range(len(data))]
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[features_for_scaling] = Logistic_Regression_Model_V2.sc.fit_transform(data[features_for_scaling])
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RSI_'+f'{leng}'] = ta.rsi(data[self.ticker], length=leng)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RSI_'+f'{leng}'] = ta.rsi(data[self.ticker], length=leng)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Stoch_Oscillator'] = stochk
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Williams_%R'] = williams_r
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ADX'] = adx['ADX_14']
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['returns'] = np.log(data[self.ticker] / data[self.ticker].shift(1)).shift(-1)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['direction'] = [1 if data.returns[i]>0 else 0 for i in range(len(data))]
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[features_for_scaling] = Logistic_Regression_Model_V2.sc.fit_transform(data[features_for_scaling])
# [*********************100%%**********************]  1 of 1 completed
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RSI_'+f'{leng}'] = ta.rsi(data[self.ticker], length=leng)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RSI_'+f'{leng}'] = ta.rsi(data[self.ticker], length=leng)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Stoch_Oscillator'] = stochk
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Williams_%R'] = williams_r
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ADX'] = adx['ADX_14']
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['returns'] = np.log(data[self.ticker] / data[self.ticker].shift(1)).shift(-1)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['direction'] = [1 if data.returns[i]>0 else 0 for i in range(len(data))]
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[features_for_scaling] = Logistic_Regression_Model_V2.sc.fit_transform(data[features_for_scaling])
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RSI_'+f'{leng}'] = ta.rsi(data[self.ticker], length=leng)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RSI_'+f'{leng}'] = ta.rsi(data[self.ticker], length=leng)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Stoch_Oscillator'] = stochk
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Williams_%R'] = williams_r
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ADX'] = adx['ADX_14']
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['returns'] = np.log(data[self.ticker] / data[self.ticker].shift(1)).shift(-1)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['direction'] = [1 if data.returns[i]>0 else 0 for i in range(len(data))]
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[features_for_scaling] = Logistic_Regression_Model_V2.sc.fit_transform(data[features_for_scaling])
# [*********************100%%**********************]  1 of 1 completed
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RSI_'+f'{leng}'] = ta.rsi(data[self.ticker], length=leng)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RSI_'+f'{leng}'] = ta.rsi(data[self.ticker], length=leng)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Stoch_Oscillator'] = stochk
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Williams_%R'] = williams_r
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ADX'] = adx['ADX_14']
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['returns'] = np.log(data[self.ticker] / data[self.ticker].shift(1)).shift(-1)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['direction'] = [1 if data.returns[i]>0 else 0 for i in range(len(data))]
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[features_for_scaling] = Logistic_Regression_Model_V2.sc.fit_transform(data[features_for_scaling])
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_'+f'{leng}'] = sma
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EMA_'+f'{leng}'] = ema
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RSI_'+f'{leng}'] = ta.rsi(data[self.ticker], length=leng)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RSI_'+f'{leng}'] = ta.rsi(data[self.ticker], length=leng)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Stoch_Oscillator'] = stochk
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Williams_%R'] = williams_r
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ADX'] = adx['ADX_14']
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['returns'] = np.log(data[self.ticker] / data[self.ticker].shift(1)).shift(-1)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['direction'] = [1 if data.returns[i]>0 else 0 for i in range(len(data))]
# /home/brian/Desktop/Projects/final_year_project/models/Logistic_Regression_Model_V2.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[features_for_scaling] = Logistic_Regression_Model_V2.sc.fit_transform(data[features_for_scaling])

# %%
accuracies = list(stock_accuracy.values())
  
fig = plt.figure(figsize = (10, 5))
 
plt.bar(tickers, accuracies, color ='maroon', 
        width = 0.4)
 
plt.xlabel("Tickers")
plt.ylabel("Accuracy")
plt.title("Accuracies of Logistic Regression models for stocks")
plt.show()

# %%
f1_scores = list(stock_f1_scores.values())
  
fig = plt.figure(figsize = (10, 5))
 
plt.bar(tickers, f1_scores, color ='maroon', 
        width = 0.4)
 
plt.xlabel("Tickers")
plt.ylabel("Accuracy")
plt.title("F1_scores for Logistic Regression models for stocks")
plt.show()

# %%
fig, axes = plt.subplots(nrows=3, ncols=2)
fig.set_figheight(15)
fig.set_figwidth(15)
i = j = 0

for ticker in tickers:
    stock_roc_curve = stock_roc_curves[ticker]
    axes[i, j].plot(stock_roc_curve["fpr"], stock_roc_curve["tpr"])
    axes[i, j].set_title(f"{ticker} ROC curve")
    axes[i, j].set_xlabel('False Positive Rate (FPR)')
    axes[i, j].set_ylabel('True Positive Rate (TPR)')
    i = (i + 1) % 3
    j = (j + 1) % 2

fig.show()
# Out:
# /tmp/ipykernel_17530/2453904697.py:15: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
stock_accuracy
# Out:
# {'GOOG': 0.511986301369863,
#  'MSFT': 0.5051369863013698,
#  'AMZN': 0.5068493150684932,
#  'AAPL': 0.5299657534246576,
#  'META': 0.5215311004784688}

# %%
stock_f1_scores
# Out:
# {'GOOG': 0.594017094017094,
#  'MSFT': 0.5621212121212121,
#  'AMZN': 0.5972027972027971,
#  'AAPL': 0.6927811975377728,
#  'META': 0.6204933586337761}
